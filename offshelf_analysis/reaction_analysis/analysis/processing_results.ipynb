# %% [markdown]
# # Processing results from different VLMs

# %%
#imports
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy import stats
#remove warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Local VLMs for scenario prediction (from frames)

# %%
# Load and process VLM frame prediction results
def load_results(directory):
    results = pd.DataFrame()
    full_results = pd.DataFrame()
    
    for filename in os.listdir(directory):
        if filename.startswith('results_'):
            filepath = os.path.join(directory, filename)
            df = pd.read_csv(filepath)
            
            # Extract model name and dataset type from filename
            # Format: results_modelname_Xs.csv (e.g., results_gemma3_1s.csv)
            base_name = filename[8:-4]  # Remove 'results_' and '.csv'
            
            # Split by underscore and check if last part is dataset duration (1s, 3s, etc.)
            parts = base_name.split('_')
            if len(parts) >= 2 and parts[-1].endswith('s') and parts[-1][:-1].isdigit():
                # Last part is duration (1s, 3s, etc.)
                dataset_duration = parts[-1]
                model_base_name = '_'.join(parts[:-1])
                model_name = f"{model_base_name}_{dataset_duration}"
            else:
                # Fallback: use full base name
                model_name = base_name
                dataset_duration = "unknown"
            
            df['model'] = model_name
            df['dataset_duration'] = dataset_duration
            
            print(f'Loading {filename}')
            print(f'  Model: {model_name}')
            print(f'  Dataset duration: {dataset_duration}')
            print(f'  Rows: {len(df)}')
            
            # Make model first column
            df = df[['model', 'dataset_duration'] + [col for col in df.columns if col not in ['model', 'dataset_duration']]]
            
            # Clean and validate outcome predictions
            df['outcome_prediction'] = df['outcome_prediction'].astype(str).str.strip().str.lower()
            df['outcome_prediction'] = df['outcome_prediction'].str.replace(r'[^\w\s]', '', regex=True)
            
            # Filter for valid predictions only
            # Accept 'well' or 'poorly', tolerate case and optional trailing period
            cleaned_pred = df['outcome_prediction'].astype(str).str.strip().str.lower().str.rstrip('.')
            valid_predictions = cleaned_pred.isin(['well', 'poorly'])
            #print if not
            for pred in df['outcome_prediction'][~valid_predictions].unique():
                print(f'  Invalid prediction found: "{pred}"')
            df_clean = df[valid_predictions].copy()
            
            print(f'  Valid predictions: {len(df_clean)}/{len(df)} ({len(df_clean)/len(df)*100:.1f}%)')
            
            if df_clean.empty:
                print(f'  No valid predictions found in {filename}')
                continue
            
            # Extract video name from frame filename
            # Expected format: q_X_main_Y_30fps_frameZZZZ.png -> q_X
            def extract_video_name(frame_file):
                try:
                    # Remove .png extension and extract video ID
                    base_name = frame_file.replace('.png', '')
                    # Split by underscore and take first two parts (q_X)
                    parts = base_name.split('_')
                    if len(parts) >= 2:
                        video_id = f"{parts[0]}_{parts[1]}"  # e.g., "q_10"
                        return video_id
                    return frame_file  # fallback
                except:
                    return frame_file  # fallback
            
            df_clean['video_name'] = df_clean['frame_file'].apply(extract_video_name)
            
            # Remove warmup videos BEFORE calculating statistics
            print(f'  Before removing warmup: {len(df_clean)} predictions')
            df_clean = df_clean[~df_clean['video_name'].str.contains('warmup', case=False, na=False)]
            print(f'  After removing warmup: {len(df_clean)} predictions')
            
            # Check extracted video names (after warmup removal)
            unique_videos = df_clean['video_name'].nunique()
            print(df_clean['video_name'].unique())
            unique_participants = df_clean['participant'].nunique()
            print(f'  Extracted {unique_videos} unique videos from {unique_participants} participants')
            #print(f'  Sample video names: {df_clean["video_name"].unique()[:5].tolist()}')
            
            # Group by participant and video, then take mode of predictions
            print(f'  Grouping by participant and video...')

            #save full csv
            full_csv_path = os.path.join('./results_analysis', f'full_results_{model_name}_{dataset_duration}.csv')
            df_clean.to_csv(full_csv_path, index=False)
            print(f'  Saved full results to {full_csv_path}')
            
            # Function to calculate mode for each participant-video combination
            def calculate_mode_for_group(group):
                predictions = group['outcome_prediction'].values
                
                # Calculate mode (most frequent prediction)
                try:
                    mode_series = pd.Series(predictions).mode()
                    if len(mode_series) > 0:
                        mode_prediction = mode_series.iloc[0]
                    else:
                        mode_prediction = predictions[0]  # fallback to first prediction
                except:
                    mode_prediction = predictions[0]  # fallback
                
                return pd.Series({
                    'outcome_prediction': mode_prediction,
                    'frame_count': len(group),
                    'frame_files': '; '.join(group['frame_file'].tolist()),
                    'model': group['model'].iloc[0],
                    'dataset_duration': group['dataset_duration'].iloc[0]
                })
            
            # Group by BOTH participant AND video_name, then apply mode calculation
            grouped = df_clean.groupby(['participant', 'video_name']).apply(calculate_mode_for_group).reset_index()
            
            # Save grouped results to CSV
            grouped_csv_path = os.path.join('./results_analysis', f'grouped_results_{model_name}_{dataset_duration}.csv')
            grouped.to_csv(grouped_csv_path, index=False)
            print(f'  Saved grouped results to {grouped_csv_path}')
            
            print(f'  Created {len(grouped)} grouped video predictions')
            
            # Calculate expected combinations
            expected_combinations = unique_participants * unique_videos
            actual_combinations = len(grouped)
            coverage = actual_combinations / expected_combinations * 100 if expected_combinations > 0 else 0
            print(f'  Expected combinations: {unique_participants} participants × {unique_videos} videos = {expected_combinations}')
            print(f'  Actual combinations: {actual_combinations}')
            print(f'  Coverage: {coverage:.1f}%')
            
            # Debug: Check if any participant-video combinations are missing
            if coverage < 100:
                all_participants = df_clean['participant'].unique()
                all_videos = df_clean['video_name'].unique()
                expected_pairs = set((p, v) for p in all_participants for v in all_videos)
                actual_pairs = set(df_clean[['participant', 'video_name']].apply(tuple, axis=1))
                missing_pairs = expected_pairs - actual_pairs
                print(f'  Missing participant-video pairs: {len(missing_pairs)}')
                if len(missing_pairs) > 0:
                    print(f'  Sample missing pairs: {list(missing_pairs)[:3]}')
            
            # Add to results
            full_results = pd.concat([full_results, grouped], ignore_index=True)
            results = pd.concat([results, df_clean], ignore_index=True)
            
            print(f'  Successfully processed {filename}\n')
    
    print(f'Total results: {len(results)} individual frame predictions')
    print(f'Total grouped results: {len(full_results)} video-level predictions')
    
    return results, full_results

# %%
path = '../results/'
results, full_results = load_results(path)

print("\nProcessing and cleaning results...")
print(f"Raw results shape: {results.shape}")
print(f"Grouped results shape: {full_results.shape}")

# Remove any remaining error entries
if 'outcome_prediction' in results.columns:
    results = results[~results['outcome_prediction'].str.contains("error", case=False, na=False)]
if 'outcome_prediction' in full_results.columns:
    full_results = full_results[~full_results['outcome_prediction'].str.contains("error", case=False, na=False)]

print(f"After error removal:")
print(f"Raw results shape: {results.shape}")
print(f"Grouped results shape: {full_results.shape}")

# Save the results
results.to_csv('all_frame_predictions.csv', index=False)
full_results.to_csv('all_video_predictions_grouped.csv', index=False)

# Show detailed summary statistics
print(f"\n" + "="*60)
print("SUMMARY STATISTICS")
print("="*60)

print(f"\nUnique models found: {len(full_results['model'].unique())}")
for model in sorted(full_results['model'].unique()):
    print(f"  - {model}")

print(f"\nDetailed breakdown by model and dataset:")
for model in sorted(full_results['model'].unique()):
    model_data = full_results[full_results['model'] == model]
    n_participants = model_data['participant'].nunique()
    n_videos = model_data['video_name'].nunique()
    dataset_duration = model_data['dataset_duration'].iloc[0] if len(model_data) > 0 else "unknown"
    
    print(f"\n{model}:")
    print(f"  Dataset duration: {dataset_duration}")
    print(f"  Participants: {n_participants}")
    print(f"  Videos: {n_videos}")
    print(f"  Total predictions: {len(model_data)}")

# Show dataset duration breakdown
print(f"\nDataset duration breakdown:")
if 'dataset_duration' in full_results.columns:
    duration_counts = full_results['dataset_duration'].value_counts()
    for duration, count in duration_counts.items():
        print(f"  {duration}: {count} predictions")

print(f"\nVideo name examples:")
print(full_results['video_name'].unique()[:10])
# Out:
# Loading results_qwen3_3s.csv
#   Model: qwen3_3s
#   Dataset duration: 3s
#   Rows: 3312
#   Invalid prediction found: "error analyzing image httpconnectionpoolhostlocalhost port11434 read timed out read timeout600"
#   Valid predictions: 3310/3312 (99.9%)
#   Before removing warmup: 3310 predictions
#   After removing warmup: 3064 predictions
# ['q_10' 'q_12' 'q_14' 'q_15' 'q_17' 'q_20' 'q_23' 'q_24' 'q_25' 'q_29'
#  'q_2' 'q_30' 'q_4' 'q_6' 'q_11' 'q_1' 'q_21' 'q_22' 'q_26' 'q_3' 'q_5'
#  'q_7' 'q_8' 'q_16' 'q_18' 'q_27' 'q_9' 'q_13' 'q_19' 'q_28']
#   Extracted 30 unique videos from 30 participants
#   Grouping by participant and video...
#   Saved full results to ./results_analysis/full_results_qwen3_3s_3s.csv
#   Saved grouped results to ./results_analysis/grouped_results_qwen3_3s_3s.csv
#   Created 511 grouped video predictions
#   Expected combinations: 30 participants × 30 videos = 900
#   Actual combinations: 511
#   Coverage: 56.8%
#   Missing participant-video pairs: 389
# ...

# %%
# Detailed analysis of prediction counts and grouping
print("="*60)
print("DETAILED PREDICTION ANALYSIS")
print("="*60)

for model in sorted(full_results['model'].unique()):
    print(f"\nModel: {model}")
    model_results = full_results[full_results['model'] == model]
    
    # Count predictions
    poorly_count = model_results['outcome_prediction'].str.contains('poorly', case=False, na=False).sum()
    well_count = model_results['outcome_prediction'].str.contains('well', case=False, na=False).sum()
    total_predictions = len(model_results)
    
    print(f"  Total predictions: {total_predictions}")
    print(f"  Poorly: {poorly_count}")
    print(f"  Well: {well_count}")
    print(f"  Other/Invalid: {total_predictions - poorly_count - well_count}")
    
    # Check for unique participants and videos
    unique_participants = model_results['participant'].nunique()
    unique_videos = model_results['video_name'].nunique()
    unique_combinations = len(model_results[['participant', 'video_name']].drop_duplicates())
    
    print(f"  Unique participants: {unique_participants}")
    print(f"  Unique videos: {unique_videos}")
    print(f"  Unique participant-video combinations: {unique_combinations}")
    
    # Check for duplicates
    if total_predictions != unique_combinations:
        print(f"  ⚠️  WARNING: Duplicates found!")
        duplicates = model_results.groupby(['participant', 'video_name']).size()
        duplicate_entries = duplicates[duplicates > 1]
        if len(duplicate_entries) > 0:
            print(f"  Duplicate participant-video combinations: {len(duplicate_entries)}")
            print(f"  Sample duplicates: {duplicate_entries.head()}")
    
    # Check prediction values
    unique_predictions = model_results['outcome_prediction'].unique()
    print(f"  Unique prediction values: {unique_predictions}")

# Overall summary
print(f"\n" + "="*60)
print("OVERALL SUMMARY")
print("="*60)
print(f"Total grouped predictions: {len(full_results)}")
print(f"Expected max predictions per model: participants × videos")
for model in sorted(full_results['model'].unique()):
    model_data = full_results[full_results['model'] == model]
    n_participants = model_data['participant'].nunique()
    n_videos = model_data['video_name'].nunique()
    actual_predictions = len(model_data)
    expected_max = n_participants * n_videos
    print(f"  {model}: {actual_predictions}/{expected_max} predictions ({actual_predictions/expected_max*100:.1f}% coverage)")
# Out:
# ...
# DETAILED PREDICTION ANALYSIS
# ...
#
# Model: deepseek-ocr_1s
#   Total predictions: 895
#   Poorly: 0
#   Well: 895
#   Other/Invalid: 0
#   Unique participants: 30
#   Unique videos: 30
#   Unique participant-video combinations: 895
#   Unique prediction values: ['well']
#
# Model: deepseek-ocr_3s
#   Total predictions: 511
#   Poorly: 0
#   Well: 511
#   Other/Invalid: 0
#   Unique participants: 30
#   Unique videos: 30
#   Unique participant-video combinations: 511
#   Unique prediction values: ['well']
#
# Model: gemma3_1s
#   Total predictions: 895
#   Poorly: 875
#   Well: 20
#   Other/Invalid: 0
#   Unique participants: 30
#   Unique videos: 30
#   Unique participant-video combinations: 895
#   Unique prediction values: ['poorly' 'well']
#
# Model: gemma3_3s
#   Total predictions: 511
#   Poorly: 502
#   Well: 9
#   Other/Invalid: 0
#   Unique participants: 30
#   Unique videos: 30
#   Unique participant-video combinations: 511
#   Unique prediction values: ['poorly' 'well']
#
# ...

# %%
# ===================================================================
# Fix Video Name Mapping Issue and Add Ground Truth Column
# ===================================================================
print("\n" + "="*50)
print("Fixing Video Name Mapping and Adding Ground Truth")
print("="*50)

# Read the ground truth file to get the proper mapping
gt_df_full = pd.read_csv('../../../offshelf_analysis/dataset_scenarios/analyze_predictions.csv')
print(f"Loaded ground truth data: {len(gt_df_full)} videos")

# Create mapping from question format (q_X) to true outcome (1=poorly, 0=well)
question_to_outcome = dict(zip(gt_df_full['Question Mapping'], gt_df_full['True Outcome']))
print("Question to True Outcome mapping (sample):")
for i, (q, outcome) in enumerate(list(question_to_outcome.items())[:5]):
    outcome_label = "poorly" if outcome == 1 else "well"
    print(f"   {q} -> {outcome} ({outcome_label})")

# Add true outcome column to full_results
print(f"\nAdding ground truth column to results...")
print(f"Before mapping: {len(full_results)} predictions")

# Map video names to true outcomes
full_results['true_outcome'] = full_results['video_name'].map(question_to_outcome)

# Check how many predictions got successfully mapped
mapped_count = full_results['true_outcome'].notna().sum()
unmapped_count = full_results['true_outcome'].isna().sum()
print(f"Successfully mapped: {mapped_count}")
print(f"Unmapped (no ground truth): {unmapped_count}")

if unmapped_count > 0:
    unmapped_videos = full_results[full_results['true_outcome'].isna()]['video_name'].unique()
    print(f"Unmapped video names: {unmapped_videos[:5]}")

# Show mapping verification
print(f"\nMapping verification:")
print("Sample video mappings from results:")
sample_mapping = full_results[['video_name', 'true_outcome']].drop_duplicates().head()
for _, row in sample_mapping.iterrows():
    outcome_label = "poorly" if row['true_outcome'] == 1 else ("well" if row['true_outcome'] == 0 else "unknown")
    print(f"   {row['video_name']} -> {row['true_outcome']} ({outcome_label})")

# Save updated results
print(f"\nSaving updated results with ground truth...")
full_results.to_csv('all_video_predictions_with_ground_truth.csv', index=False)
print(f"Saved to: all_video_predictions_with_ground_truth.csv")
# Out:
# ...
# Fixing Video Name Mapping and Adding Ground Truth
# ...
# Loaded ground truth data: 30 videos
# Question to True Outcome mapping (sample):
#    q_2 -> 1 (poorly)
#    q_3 -> 1 (poorly)
#    q_4 -> 1 (poorly)
#    q_5 -> 1 (poorly)
#    q_6 -> 1 (poorly)
#
# Adding ground truth column to results...
# Before mapping: 9798 predictions
# Successfully mapped: 9798
# Unmapped (no ground truth): 0
#
# Mapping verification:
# Sample video mappings from results:
#    q_10 -> 0 (well)
#    q_12 -> 0 (well)
#    q_14 -> 1 (poorly)
#    q_15 -> 1 (poorly)
#    q_17 -> 1 (poorly)
#
# Saving updated results with ground truth...
# Saved to: all_video_predictions_with_ground_truth.csv

# %%
# ===================================================================
# Add Human Predictions Column
# ===================================================================
print("\n" + "="*50)
print("Adding Human Predictions Column")
print("="*50)

# Load human predictions data
human_df = pd.read_csv('../../../offshelf_analysis/dataset_scenarios/badidea_ground_truth.csv')
print(f"Loaded human predictions data: {len(human_df)} individual predictions")
print(f"Unique participants: {human_df['participant_id'].nunique()}")
print(f"Unique videos: {human_df['response_video'].nunique()}")

# Filter to only include specific participant IDs
valid_participant_ids = [1048, 1251, 1483, 1676, 2103, 2313, 2698, 2946, 3157, 3203, 3339, 3882, 5009, 5099, 5124, 5233, 5310, 6488, 7136, 7782, 7797, 8184, 8436, 8758, 8786, 9055, 9385, 9777, 9941]
print(f"Filtering to only include {len(valid_participant_ids)} specific participants")
print(f"Original dataset size: {len(human_df)}")
human_df = human_df[human_df['participant_id'].isin(valid_participant_ids)]
print(f"Filtered dataset size: {len(human_df)}")
print(f"Participants after filtering: {human_df['participant_id'].nunique()}")

# Create mapping from (participant_id, video_name) to human prediction
human_prediction_map = {}
for _, row in human_df.iterrows():
    participant_id = str(row['participant_id'])  # Convert to string to match
    video_name = row['response_video']  # Already in q_X format
    human_prediction = row['class']  # 1=poorly, 0=well
    
    human_prediction_map[(participant_id, video_name)] = human_prediction

print(f"Created human prediction mapping with {len(human_prediction_map)} entries")
print("Sample human predictions:", dict(list(human_prediction_map.items())[:3]))

# Add human prediction column to full_results
def get_human_prediction(row):
    participant_id = str(row['participant'])
    video_name = row['video_name']
    return human_prediction_map.get((participant_id, video_name), np.nan)

print(f"\nAdding human prediction column to results...")
full_results['human_prediction'] = full_results.apply(get_human_prediction, axis=1)

# Check how many predictions got human matches
human_mapped_count = full_results['human_prediction'].notna().sum()
human_unmapped_count = full_results['human_prediction'].isna().sum()
print(f"Successfully mapped to human predictions: {human_mapped_count}")
print(f"Unmapped (no human prediction): {human_unmapped_count}")

if human_unmapped_count > 0:
    # Check a few unmapped entries to understand the mismatch
    unmapped_sample = full_results[full_results['human_prediction'].isna()][['participant', 'video_name']].head()
    print(f"Sample unmapped participant-video pairs:")
    for _, row in unmapped_sample.iterrows():
        print(f"   Participant: {row['participant']}, Video: {row['video_name']}")

# Show mapping verification
print(f"\nHuman prediction mapping verification:")
print("Sample participant-video-human prediction mappings:")
sample_mapping = full_results[['participant', 'video_name', 'human_prediction', 'true_outcome']].dropna().head()
for _, row in sample_mapping.iterrows():
    human_label = "poorly" if row['human_prediction'] == 1 else ("well" if row['human_prediction'] == 0 else "unknown")
    true_label = "poorly" if row['true_outcome'] == 1 else ("well" if row['true_outcome'] == 0 else "unknown")
    print(f"   Participant {row['participant']}, Video {row['video_name']}: Human={row['human_prediction']} ({human_label}), True={row['true_outcome']} ({true_label})")

# Save updated results with both ground truth and human predictions
print(f"\nSaving updated results with ground truth and human predictions...")
full_results.to_csv('all_video_predictions_with_ground_truth_and_human.csv', index=False)
print(f"Saved to: all_video_predictions_with_ground_truth_and_human.csv")

print(f"\nDataFrame columns: {full_results.columns.tolist()}")
print(f"Total predictions: {len(full_results)}")
print(f"Predictions with both ground truth and human data: {len(full_results.dropna(subset=['true_outcome', 'human_prediction']))}")
# Out:
# ...
# Adding Human Predictions Column
# ...
# Loaded human predictions data: 865 individual predictions
# Unique participants: 29
# Unique videos: 30
# Filtering to only include 29 specific participants
# Original dataset size: 865
# Filtered dataset size: 865
# Participants after filtering: 29
# Created human prediction mapping with 865 entries
# Sample human predictions: {('1048', 'q_10'): 0, ('1048', 'q_11'): 0, ('1048', 'q_12'): 1}
#
# Adding human prediction column to results...
# Successfully mapped to human predictions: 9462
# Unmapped (no human prediction): 336
# Sample unmapped participant-video pairs:
#    Participant: 5702, Video: q_1
#    Participant: 5702, Video: q_10
#    Participant: 5702, Video: q_11
#    Participant: 5702, Video: q_14
#    Participant: 5702, Video: q_15
#
# Human prediction mapping verification:
# Sample participant-video-human prediction mappings:
#    Participant 1048, Video q_10: Human=0.0 (well), True=0 (well)
# ...

# %%
# ===================================================================
# Calculate Model vs Human Agreement Metrics
# ===================================================================
print("\n" + "="*60)
print("CALCULATING MODEL vs HUMAN AGREEMENT METRICS")
print("="*60)

# First, convert text predictions to numeric for all models
print("Converting predictions to numeric format...")
full_results['outcome_prediction_numeric'] = full_results['outcome_prediction'].apply(
    lambda x: 1 if 'poorly' in str(x).lower() else (0 if 'well' in str(x).lower() else np.nan)
)

# Remove any NaN predictions - need both model prediction and human prediction
full_results_clean = full_results.dropna(subset=['outcome_prediction_numeric', 'human_prediction'])
print(f"Clean predictions with both model and human data: {len(full_results_clean)}")

# Models and metrics dataframe
model_human_agreement_df = pd.DataFrame(columns=[
    'model', 'accuracy', 'precision', 'recall', 'f1_score', 
    'n_predictions', 'n_videos', 'avg_participants_per_video'
])

print("\nEvaluating model vs human agreement...")
print("Comparing individual model predictions directly with individual human predictions...")

# Evaluate each model
for model in sorted(full_results_clean['model'].unique()):
    print(f"\nProcessing model: {model}")
    model_results = full_results_clean[full_results_clean['model'] == model]
    
    # For this analysis, we compare each model prediction directly with the corresponding human prediction
    # No need to aggregate by video - we want to see how often the model agrees with individual humans
    
    y_pred = model_results['outcome_prediction_numeric'].values  # Model predictions
    y_human = model_results['human_prediction'].values           # Human predictions (treating as "truth")
    
    print(f"  Total participant-video combinations: {len(y_pred)}")
    print(f"  Unique videos: {model_results['video_name'].nunique()}")
    print(f"  Unique participants: {model_results['participant'].nunique()}")
    
    # Calculate metrics - treating human predictions as the "ground truth"
    accuracy = accuracy_score(y_human, y_pred)
    precision = precision_score(y_human, y_pred, zero_division=0)
    recall = recall_score(y_human, y_pred, zero_division=0)
    f1 = f1_score(y_human, y_pred, zero_division=0)
    
    print(f"  Agreement with humans:")
    print(f"    Accuracy: {accuracy:.3f}")
    print(f"    Precision: {precision:.3f}")
    print(f"    Recall: {recall:.3f}")
    print(f"    F1 Score: {f1:.3f}")
    
    # Show prediction distribution comparison
    model_poorly = np.sum(y_pred == 1)
    model_well = np.sum(y_pred == 0)
    human_poorly = np.sum(y_human == 1)
    human_well = np.sum(y_human == 0)
    
    print(f"  Model predictions: {model_poorly} poorly, {model_well} well")
    print(f"  Human predictions: {human_poorly} poorly, {human_well} well")
    
    # Calculate agreement rate
    agreement_rate = np.mean(y_pred == y_human)
    print(f"  Raw agreement rate: {agreement_rate:.3f} ({agreement_rate*100:.1f}%)")
    
    # Add to results dataframe
    avg_participants_per_video = len(model_results) / model_results['video_name'].nunique()
    df_pred = pd.DataFrame({
        'model': [model],
        'accuracy': [accuracy],
        'precision': [precision],
        'recall': [recall],
        'f1_score': [f1],
        'n_predictions': [len(model_results)],  # Total participant-video combinations
        'n_videos': [model_results['video_name'].nunique()],  # Unique videos
        'avg_participants_per_video': [avg_participants_per_video]
    })
    model_human_agreement_df = pd.concat([model_human_agreement_df, df_pred], ignore_index=True)

# Save the performance results
print(f"\n" + "="*60)
print("SAVING RESULTS")
print("="*60)
model_human_agreement_df.to_csv('model_human_agreement_metrics.csv', index=False)
full_results_clean.to_csv('all_predictions_with_human_and_ground_truth_clean.csv', index=False)

print("Saved files:")
print("  - model_human_agreement_metrics.csv")
print("  - all_predictions_with_human_and_ground_truth_clean.csv")

# Display final results
print(f"\n" + "="*60)
print("MODEL vs HUMAN AGREEMENT SUMMARY")
print("="*60)
model_human_agreement_df = model_human_agreement_df.sort_values('accuracy', ascending=False)
print(model_human_agreement_df.to_string(index=False, float_format='%.3f'))

model_human_agreement_df
# Out:
# ...
# CALCULATING MODEL vs HUMAN AGREEMENT METRICS
# ...
# Converting predictions to numeric format...
# Clean predictions with both model and human data: 9462
#
# Evaluating model vs human agreement...
# Comparing individual model predictions directly with individual human predictions...
#
# Processing model: deepseek-ocr_1s
#   Total participant-video combinations: 865
#   Unique videos: 30
#   Unique participants: 29
#   Agreement with humans:
#     Accuracy: 0.535
#     Precision: 0.000
#     Recall: 0.000
#     F1 Score: 0.000
#   Model predictions: 0 poorly, 865 well
#   Human predictions: 402 poorly, 463 well
#   Raw agreement rate: 0.535 (53.5%)
#
# Processing model: deepseek-ocr_3s
#   Total participant-video combinations: 493
#   Unique videos: 30
#   Unique participants: 29
#   Agreement with humans:
#     Accuracy: 0.519
#     Precision: 0.000
#     Recall: 0.000
#     F1 Score: 0.000
#   Model predictions: 0 poorly, 493 well
#   Human predictions: 237 poorly, 256 well
# ...
